# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshmadala18/CAPTAIN_SPARROWS/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=[['apple',10,240],['orange',10,20],['grapes',20,30],['pineapple',15,45]]
df1=pd.DataFrame(data,columns=['fruit_name','quantity','price'])
df1
# Out:
#   fruit_name  quantity  price
# 0      apple        10    240
# 1     orange        10     20
# 2     grapes        20     30
# 3  pineapple        15     45

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fruit_name  4 non-null      object
#  1   quantity    4 non-null      int64
#  2   price       4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df1.describe()
# Out:
#         quantity       price
# count   4.000000    4.000000
# mean   13.750000   83.750000
# std     4.787136  104.672107
# min    10.000000   20.000000
# 25%    10.000000   27.500000
# 50%    12.500000   37.500000
# 75%    16.250000   93.750000
# max    20.000000  240.000000

# %%
df1.dtypes
# Out:
# fruit_name    object
# quantity       int64
# price          int64
# dtype: object

# %%
df1['price'].value_counts()
# Out:
# 240    1
# 20     1
# 30     1
# 45     1
# Name: price, dtype: int64

# %%
df1[2:4]
# Out:
#   fruit_name  quantity  price
# 2     grapes        20     30
# 3  pineapple        15     45

# %%
df1.corr()
# Out:
# <ipython-input-16-49b3fcfeb4d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#           quantity    price
# quantity   1.00000 -0.48645
# price     -0.48645  1.00000

# %%
df1.plot()
# Out:
# <Axes: >
